# %% [markdown]
# <a href="https://colab.research.google.com/github/coatless/pyopensci-eic/blob/main/i240-iosacal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##IOSACal: open source radiocarbon calibration
# [IOSACal](http://c14.iosa.it/) is an open source tool for radiocarbon calibration. This Google Colab runs the program in the cloud. Copy it to make your own modifications.
#
# There is an example notebook, contributed by Jelmer Wind.

# %%
# !pip install iosacal
# Out:
# Collecting iosacal
#   Downloading iosacal-0.6.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from iosacal) (2.0.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from iosacal) (1.15.3)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.11/dist-packages (from iosacal) (3.10.0)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.11/dist-packages (from iosacal) (8.1.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->iosacal) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->iosacal) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->iosacal) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->iosacal) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->iosacal) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->iosacal) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->iosacal) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->iosacal) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->iosacal) (1.17.0)
# Downloading iosacal-0.6.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.5/536.5 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: iosacal
# Successfully installed iosacal-0.6.0

# %%
from iosacal import R
from iosacal.text import single_text
r = R(8000, 40, 'P-769')
cal_r = r.calibrate('intcal13')
print(single_text(cal_r))
# Out:
# # P-769
#
# Calibration of P-769: 8000 ± 40 BP
#
# ## Calibrated age
#
# Atmospheric data from Reimer et al (2013);
#
# ### 68.2% probability
#
# * 8995 CalBP - 8950 CalBP (18.5%)
# * 8940 CalBP - 8934 CalBP (2.4%)
# * 8920 CalBP - 8861 CalBP (24.5%)
# * 8833 CalBP - 8780 CalBP (22.7%)
#
# ### 95.4% probability
#
# * 9008 CalBP - 8718 CalBP (95.3%)
#
# ----
#
# IOSACal v0.6.0

# %%
from iosacal import iplot
iplot(cal_r)

# %% [markdown]
# Multiple determinations from the same event can be checked for consistency and combined

# %%
from iosacal import R, combine
from iosacal.text import single_text

r1 = R(4430, 100, 'Birm-637')
r2 = R(4430, 120, 'Birm-638')
r3 = R(4400, 100, 'Birm-639')
r4 = R(4350, 130, 'Birm-636')
r_combined = combine([r1, r2, r3, r4])
print(r_combined)
# Out:
# RadiocarbonSample( Combined from Birm-637, Birm-638, Birm-639, Birm-636 with test statistic 0.287 : 4406 ± 55 )

# %%
r_combined_cal = r_combined.calibrate('intcal13')
print(single_text(r_combined_cal))
# Out:
# # Combined from Birm-637, Birm-638, Birm-639, Birm-636 with test statistic 0.287
#
# Calibration of Combined from Birm-637, Birm-638, Birm-639, Birm-636 with test statistic 0.287: 4406.465763017056 ± 55.163983474505095 BP
#
# ## Calibrated age
#
# Atmospheric data from Reimer et al (2013);
#
# ### 68.2% probability
#
# * 5210 CalBP - 5203 CalBP (2.2%)
# * 5047 CalBP - 4870 CalBP (65.8%)
#
# ### 95.4% probability
#
# * 5280 CalBP - 5164 CalBP (19.3%)
# * 5135 CalBP - 5105 CalBP (3.6%)
# * 5077 CalBP - 4855 CalBP (72.5%)
#
# ----
#
# IOSACal v0.6.0
